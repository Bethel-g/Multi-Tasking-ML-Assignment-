# %% [markdown]
# # Student Performance Prediction using Multi-Task Learning
#
# This notebook demonstrates the regularization power of Multi-Task Learning (MTL).
#
# ## 1. Problem Statement
# We aim to predict:
# - **Task 1 (Regression)**: Final Math Score.
# - **Task 2 (Classification)**: Pass/Fail status.
#
# ## 2. Methodology
# We compare a complex STL model (prone to overfitting) against an MTL model that shares knowledge between tasks.

# %%
import pandas as pd
df = pd.read_csv('../dataset/student_performance.csv')
df.head()
